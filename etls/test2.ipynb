# %%
import pandas as pd
import requests
import json

download_url = 'https://lantern.healthit.gov/api/organizations/v1'

lantern_df = pd.read_csv(download_url)

# %%
npis_df=lantern_df.loc[lantern_df['identifier_type'].apply(lambda x: 'npi' in str(x).lower())]
npis_df['identifier_type']=npis_df['identifier_type'].str.split('\n')
npis_df['identifier_value']=npis_df['identifier_value'].str.split('\n')
normalized_ids = npis_df.explode(['identifier_type','identifier_value'])
normalized_npis = normalized_ids.loc[normalized_ids['identifier_type'].str.lower() == 'npi']
normalized_npis['fhir_endpoint_url']=normalized_npis['fhir_endpoint_url'].str.split('\n')
normalized_endpoints = normalized_npis.explode('fhir_endpoint_url')
# Out:
# /var/folders/zt/jvxrh15j40sfz4x_sldwpck00000gp/T/ipykernel_31463/1356522144.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   npis_df['identifier_type']=npis_df['identifier_type'].str.split('\n')
# /var/folders/zt/jvxrh15j40sfz4x_sldwpck00000gp/T/ipykernel_31463/1356522144.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   npis_df['identifier_value']=npis_df['identifier_value'].str.split('\n')

# %%
normalized_endpoints
# Out:
#                            organization_name identifier_type identifier_value  \
# 0                                          -             NPI       1922195171
# 0                                          -             NPI       1922195171
# 1                                          -             NPI       1457626558
# 1                                          -             NPI       1457626558
# 1                                          -             NPI       1467815928
# ...                                      ...             ...              ...
# 192056  ZZ_YUCCA VALLEY FAMILY MEDICAL ASSOC             NPI       1487661518
# 192057               ZZ_YVONNE MORGAN MD INC             NPI       1234567893
# 192058                           ZZZCCFC LAB             NPI       1134173859
# 192059             ZZZ DANIEL MASSIAH LEGACY             NPI       1114958691
# 192060              ZZZTHE TRAINING PRACTICE             NPI       1467490433
#
#                                                   address  \
# 0       1431 SW 1ST AVE, OCALA, FL, 34471-6500\n1451 E...
# 0       1431 SW 1ST AVE, OCALA, FL, 34471-6500\n1451 E...
# 1       104 EAST ROUTE 59, NANUET, NY, 10954-2957\n200...
# 1       104 EAST ROUTE 59, NANUET, NY, 10954-2957\n200...
# 1       104 EAST ROUTE 59, NANUET, NY, 10954-2957\n200...
# ...                                                   ...
# 192056  57463 29 PALMS HIGHWAY,SUITE 203, YUCCA VALLEY...
# 192057  1080 N INDIAN CANYON DR,SUITE 200, PALM SPRING...
# 192058  821 E CHAPEL STREET SUITE 203, SANTA MARIA, CA...
# 192059        1300 ROANOKE AVE, RIVERHEAD, NY, 11901, USA
# 192060            63 S ROCKFORD DR, TEMPE, AZ, 85281, USA
#
#                                         fhir_endpoint_url fhir_version  \
# 0       https://api.platform.athenahealth.com/1045/bra...        4.0.1
# 0          https://api.platform.athenahealth.com/fhir/r4/        4.0.1
# 1       https://api.platform.athenahealth.com/5622/bra...        4.0.1
# 1          https://api.platform.athenahealth.com/fhir/r4/        4.0.1
# 1       https://api.platform.athenahealth.com/5622/bra...        4.0.1
# ...                                                   ...          ...
# 192056  https://fhir.nextgen.com/nge/prod/fhir-api-r4/...        4.0.1
# 192057  https://fhir.nextgen.com/nge/prod/fhir-api-r4/...        4.0.1
# 192058  https://fhir.emdscloud.com/infor/CustomerApi/f...  No Cap Stat
# 192059  https://fhir.nextgen.com/nge/prod/fhir-api-r4/...        4.0.1
# 192060  https://fhir.nextgen.com/nge/prod/fhir-api-r4/...        4.0.1
#
#                   vendor_name
# 0          athenahealth, Inc.
# 0          athenahealth, Inc.
# 1          athenahealth, Inc.
# 1          athenahealth, Inc.
# 1          athenahealth, Inc.
# ...                       ...
# 192056     NextGen Healthcare
# 192057     NextGen Healthcare
# 192058  CompuGroup Medical US
# 192059     NextGen Healthcare
# 192060     NextGen Healthcare
#
# [1142405 rows x 7 columns]
